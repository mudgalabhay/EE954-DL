# %% [markdown]
# ### Question 1
# Download the Fashion_MNIST dataset. You can find it on the official Fashion-MNIST website or by using PyTorch's torchvision.datasets module. Split the dataset into training, validation and testing sets. A common split is 80% of the data to train, 10% to validate, and 10% to test scenarios, but you can adjust this as needed. Normalize the images. This involves scaling the pixel values to a range between 0 and 1.

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Define transformations for the dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize to [-1, 1] range
])

# Download and load the FashionMNIST dataset
dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)

# Define the size of each split
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

# Split the dataset
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# Create data loaders for each split
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Print sizes to verify
print(f"Training set size: {train_size}")
print(f"Validation set size: {val_size}")
print(f"Test set size: {test_size}")
# Out:
# Training set size: 48000
# Validation set size: 6000
# Test set size: 6000

# %% [markdown]
# ### Question 2
# Implement a MLP for classification.

# %% [markdown]
# #### a) Flatten the images into a single dimensional vector before feeding it to the model.
# #### b) Write a pre-processing module for all the images.
# #### c) Write the Forward pass from scratch.

# %%
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(28*28, 256)  # First fully connected layer
        self.fc2 = nn.Linear(256, 128)    # Second fully connected layer
        self.fc3 = nn.Linear(128, 10)     # Output layer

    def forward(self, x):
        # a. Flatten the images
        x = x.view(-1, 28*28)
        
        # First layer with ReLU activation
        x = torch.relu(self.fc1(x))
        
        # Second layer with ReLU activation
        x = torch.relu(self.fc2(x))
        
        # Output layer
        x = self.fc3(x)
        
        return x

model = MLP()

# %% [markdown]
# #### d)Write the Backward pass from scratch.

# %%
def backward_pass(model, loss, learning_rate):
    # Zero the gradients
    for param in model.parameters():
        if param.grad is not None:
            param.grad.data.zero_()
    
    # Compute gradients
    loss.backward()
    
    # Update parameters
    with torch.no_grad():
        for param in model.parameters():
            param -= learning_rate * param.grad

# %% [markdown]
# #### e) Write the module for cross entropy loss

# %% [markdown]
# def cross_entropy_loss(output, target):
#     # Apply softmax to output
#     softmax_output = torch.softmax(output, dim=1)
#
#     # Calculate cross-entropy loss
#     loss = -torch.sum(target * torch.log(softmax_output))
#     return loss

# %% [markdown]
# #### f) Experiment with different hyperparameters like number of layers, dropout, objective function, etc. and settle with a combination which performs the best for the given problem

# %%
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self, input_size=28*28, hidden_sizes=[256, 128], output_size=10, dropout_prob=0.0):
        super(MLP, self).__init__()
        layers = []
        current_size = input_size
        
        for hidden_size in hidden_sizes:
            layers.append(nn.Linear(current_size, hidden_size))
            layers.append(nn.ReLU())
            if dropout_prob > 0:
                layers.append(nn.Dropout(dropout_prob))
            current_size = hidden_size
        
        layers.append(nn.Linear(current_size, output_size))
        self.network = nn.Sequential(*layers)
    
    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten the images
        return self.network(x)

# %%
import torch.optim as optim

def train_and_evaluate(model, train_loader, val_loader, num_epochs, learning_rate, criterion):
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    
    for epoch in range(num_epochs):
        model.train()
        for images, labels in train_loader:
            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            # Backward pass
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        # Validation
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_loss /= len(val_loader)
        val_accuracy = 100 * correct / total
        print(f'Epoch [{epoch+1}/{num_epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
    
    return val_loss, val_accuracy

# %%
# Hyperparameter configurations
hidden_layer_configs = [
    [256],
    [256, 128],
    [512, 256, 128]
]
dropout_probs = [0.0, 0.2, 0.5]
learning_rates = [0.01, 0.001]
num_epochs = 10

best_val_loss = float('inf')
best_model = None
best_config = {}

# Experiment with different hyperparameters
for hidden_layers in hidden_layer_configs:
    for dropout_prob in dropout_probs:
        for lr in learning_rates:
            print(f'Experimenting with hidden_layers={hidden_layers}, dropout_prob={dropout_prob}, learning_rate={lr}')
            model = MLP(input_size=28*28, hidden_sizes=hidden_layers, output_size=10, dropout_prob=dropout_prob)
            criterion = nn.CrossEntropyLoss()
            val_loss, val_accuracy = train_and_evaluate(model, train_loader, val_loader, num_epochs, lr, criterion)
            
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model = model
                best_config = {
                    'hidden_layers': hidden_layers,
                    'dropout_prob': dropout_prob,
                    'learning_rate': lr,
                    'val_loss': val_loss,
                    'val_accuracy': val_accuracy
                }

print(f'Best Configuration: {best_config}')
# Out:
# Experimenting with hidden_layers=[256], dropout_prob=0.0, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.6025, Validation Accuracy: 79.12%
# Epoch [2/10], Validation Loss: 0.5331, Validation Accuracy: 81.55%
# Epoch [3/10], Validation Loss: 0.4955, Validation Accuracy: 82.63%
# Epoch [4/10], Validation Loss: 0.4742, Validation Accuracy: 83.23%
# Epoch [5/10], Validation Loss: 0.4633, Validation Accuracy: 83.70%
# Epoch [6/10], Validation Loss: 0.4479, Validation Accuracy: 84.27%
# Epoch [7/10], Validation Loss: 0.4516, Validation Accuracy: 83.95%
# Epoch [8/10], Validation Loss: 0.4299, Validation Accuracy: 84.67%
# Epoch [9/10], Validation Loss: 0.4281, Validation Accuracy: 84.77%
# Epoch [10/10], Validation Loss: 0.4190, Validation Accuracy: 85.17%
# Experimenting with hidden_layers=[256], dropout_prob=0.0, learning_rate=0.001
# Epoch [1/10], Validation Loss: 1.3085, Validation Accuracy: 68.35%
# Epoch [2/10], Validation Loss: 0.9563, Validation Accuracy: 73.18%
# Epoch [3/10], Validation Loss: 0.8165, Validation Accuracy: 74.50%
# Epoch [4/10], Validation Loss: 0.7444, Validation Accuracy: 75.57%
# Epoch [5/10], Validation Loss: 0.6995, Validation Accuracy: 76.43%
# Epoch [6/10], Validation Loss: 0.6683, Validation Accuracy: 77.10%
# Epoch [7/10], Validation Loss: 0.6445, Validation Accuracy: 77.70%
# Epoch [8/10], Validation Loss: 0.6252, Validation Accuracy: 78.32%
# Epoch [9/10], Validation Loss: 0.6093, Validation Accuracy: 78.92%
# Epoch [10/10], Validation Loss: 0.5954, Validation Accuracy: 79.28%
# Experimenting with hidden_layers=[256], dropout_prob=0.2, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.6098, Validation Accuracy: 78.85%
# Epoch [2/10], Validation Loss: 0.5370, Validation Accuracy: 81.23%
# Epoch [3/10], Validation Loss: 0.4972, Validation Accuracy: 82.70%
# Epoch [4/10], Validation Loss: 0.4806, Validation Accuracy: 83.18%
# Epoch [5/10], Validation Loss: 0.4614, Validation Accuracy: 83.68%
# Epoch [6/10], Validation Loss: 0.4434, Validation Accuracy: 84.38%
# Epoch [7/10], Validation Loss: 0.4339, Validation Accuracy: 84.63%
# Epoch [8/10], Validation Loss: 0.4247, Validation Accuracy: 84.68%
# Epoch [9/10], Validation Loss: 0.4167, Validation Accuracy: 85.20%
# Epoch [10/10], Validation Loss: 0.4110, Validation Accuracy: 85.22%
# Experimenting with hidden_layers=[256], dropout_prob=0.2, learning_rate=0.001
# Epoch [1/10], Validation Loss: 1.3364, Validation Accuracy: 66.18%
# Epoch [2/10], Validation Loss: 0.9903, Validation Accuracy: 71.83%
# Epoch [3/10], Validation Loss: 0.8450, Validation Accuracy: 74.12%
# Epoch [4/10], Validation Loss: 0.7675, Validation Accuracy: 74.98%
# Epoch [5/10], Validation Loss: 0.7195, Validation Accuracy: 75.75%
# Epoch [6/10], Validation Loss: 0.6854, Validation Accuracy: 76.35%
# Epoch [7/10], Validation Loss: 0.6601, Validation Accuracy: 77.02%
# Epoch [8/10], Validation Loss: 0.6393, Validation Accuracy: 77.67%
# Epoch [9/10], Validation Loss: 0.6220, Validation Accuracy: 78.12%
# Epoch [10/10], Validation Loss: 0.6072, Validation Accuracy: 78.83%
# Experimenting with hidden_layers=[256], dropout_prob=0.5, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.6300, Validation Accuracy: 77.68%
# Epoch [2/10], Validation Loss: 0.5433, Validation Accuracy: 80.90%
# Epoch [3/10], Validation Loss: 0.5076, Validation Accuracy: 82.02%
# Epoch [4/10], Validation Loss: 0.4809, Validation Accuracy: 82.70%
# Epoch [5/10], Validation Loss: 0.4674, Validation Accuracy: 83.20%
# Epoch [6/10], Validation Loss: 0.4494, Validation Accuracy: 83.88%
# Epoch [7/10], Validation Loss: 0.4388, Validation Accuracy: 84.18%
# Epoch [8/10], Validation Loss: 0.4314, Validation Accuracy: 85.03%
# Epoch [9/10], Validation Loss: 0.4232, Validation Accuracy: 84.70%
# Epoch [10/10], Validation Loss: 0.4150, Validation Accuracy: 85.08%
# Experimenting with hidden_layers=[256], dropout_prob=0.5, learning_rate=0.001
# Epoch [1/10], Validation Loss: 1.3304, Validation Accuracy: 68.02%
# Epoch [2/10], Validation Loss: 0.9941, Validation Accuracy: 72.53%
# Epoch [3/10], Validation Loss: 0.8516, Validation Accuracy: 73.92%
# Epoch [4/10], Validation Loss: 0.7750, Validation Accuracy: 74.48%
# Epoch [5/10], Validation Loss: 0.7277, Validation Accuracy: 75.60%
# Epoch [6/10], Validation Loss: 0.6945, Validation Accuracy: 76.13%
# Epoch [7/10], Validation Loss: 0.6693, Validation Accuracy: 76.70%
# Epoch [8/10], Validation Loss: 0.6490, Validation Accuracy: 77.05%
# Epoch [9/10], Validation Loss: 0.6327, Validation Accuracy: 77.63%
# Epoch [10/10], Validation Loss: 0.6180, Validation Accuracy: 78.13%
# Experimenting with hidden_layers=[256, 128], dropout_prob=0.0, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.6696, Validation Accuracy: 75.87%
# Epoch [2/10], Validation Loss: 0.5628, Validation Accuracy: 79.45%
# Epoch [3/10], Validation Loss: 0.5130, Validation Accuracy: 81.93%
# Epoch [4/10], Validation Loss: 0.4796, Validation Accuracy: 82.85%
# Epoch [5/10], Validation Loss: 0.4580, Validation Accuracy: 83.80%
# Epoch [6/10], Validation Loss: 0.4505, Validation Accuracy: 83.90%
# Epoch [7/10], Validation Loss: 0.4383, Validation Accuracy: 84.57%
# Epoch [8/10], Validation Loss: 0.4266, Validation Accuracy: 84.90%
# Epoch [9/10], Validation Loss: 0.4240, Validation Accuracy: 84.75%
# Epoch [10/10], Validation Loss: 0.4178, Validation Accuracy: 84.80%
# Experimenting with hidden_layers=[256, 128], dropout_prob=0.0, learning_rate=0.001
# Epoch [1/10], Validation Loss: 1.9760, Validation Accuracy: 46.12%
# Epoch [2/10], Validation Loss: 1.4841, Validation Accuracy: 60.27%
# Epoch [3/10], Validation Loss: 1.1272, Validation Accuracy: 69.07%
# Epoch [4/10], Validation Loss: 0.9388, Validation Accuracy: 71.58%
# Epoch [5/10], Validation Loss: 0.8327, Validation Accuracy: 73.43%
# Epoch [6/10], Validation Loss: 0.7675, Validation Accuracy: 74.42%
# Epoch [7/10], Validation Loss: 0.7232, Validation Accuracy: 74.68%
# Epoch [8/10], Validation Loss: 0.6910, Validation Accuracy: 75.40%
# Epoch [9/10], Validation Loss: 0.6671, Validation Accuracy: 75.70%
# Epoch [10/10], Validation Loss: 0.6478, Validation Accuracy: 76.53%
# Experimenting with hidden_layers=[256, 128], dropout_prob=0.2, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.6782, Validation Accuracy: 75.55%
# Epoch [2/10], Validation Loss: 0.5774, Validation Accuracy: 79.18%
# Epoch [3/10], Validation Loss: 0.5264, Validation Accuracy: 80.93%
# Epoch [4/10], Validation Loss: 0.4923, Validation Accuracy: 82.23%
# Epoch [5/10], Validation Loss: 0.4758, Validation Accuracy: 83.28%
# Epoch [6/10], Validation Loss: 0.4600, Validation Accuracy: 83.57%
# Epoch [7/10], Validation Loss: 0.4464, Validation Accuracy: 84.13%
# Epoch [8/10], Validation Loss: 0.4300, Validation Accuracy: 84.77%
# Epoch [9/10], Validation Loss: 0.4256, Validation Accuracy: 84.70%
# Epoch [10/10], Validation Loss: 0.4139, Validation Accuracy: 85.23%
# Experimenting with hidden_layers=[256, 128], dropout_prob=0.2, learning_rate=0.001
# Epoch [1/10], Validation Loss: 2.0570, Validation Accuracy: 42.75%
# Epoch [2/10], Validation Loss: 1.6153, Validation Accuracy: 49.07%
# Epoch [3/10], Validation Loss: 1.2490, Validation Accuracy: 64.43%
# Epoch [4/10], Validation Loss: 1.0397, Validation Accuracy: 69.52%
# Epoch [5/10], Validation Loss: 0.9108, Validation Accuracy: 71.95%
# Epoch [6/10], Validation Loss: 0.8284, Validation Accuracy: 73.22%
# Epoch [7/10], Validation Loss: 0.7727, Validation Accuracy: 73.93%
# Epoch [8/10], Validation Loss: 0.7324, Validation Accuracy: 74.77%
# Epoch [9/10], Validation Loss: 0.7035, Validation Accuracy: 75.20%
# Epoch [10/10], Validation Loss: 0.6806, Validation Accuracy: 75.52%
# Experimenting with hidden_layers=[256, 128], dropout_prob=0.5, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.7501, Validation Accuracy: 72.50%
# Epoch [2/10], Validation Loss: 0.6170, Validation Accuracy: 77.15%
# Epoch [3/10], Validation Loss: 0.5573, Validation Accuracy: 80.12%
# Epoch [4/10], Validation Loss: 0.5207, Validation Accuracy: 81.12%
# Epoch [5/10], Validation Loss: 0.5001, Validation Accuracy: 81.78%
# Epoch [6/10], Validation Loss: 0.4793, Validation Accuracy: 82.50%
# Epoch [7/10], Validation Loss: 0.4648, Validation Accuracy: 83.18%
# Epoch [8/10], Validation Loss: 0.4508, Validation Accuracy: 83.65%
# Epoch [9/10], Validation Loss: 0.4417, Validation Accuracy: 84.05%
# Epoch [10/10], Validation Loss: 0.4347, Validation Accuracy: 84.28%
# Experimenting with hidden_layers=[256, 128], dropout_prob=0.5, learning_rate=0.001
# Epoch [1/10], Validation Loss: 2.0404, Validation Accuracy: 45.55%
# Epoch [2/10], Validation Loss: 1.6474, Validation Accuracy: 51.13%
# Epoch [3/10], Validation Loss: 1.3258, Validation Accuracy: 60.97%
# Epoch [4/10], Validation Loss: 1.1297, Validation Accuracy: 65.88%
# Epoch [5/10], Validation Loss: 1.0068, Validation Accuracy: 68.30%
# Epoch [6/10], Validation Loss: 0.9226, Validation Accuracy: 70.92%
# Epoch [7/10], Validation Loss: 0.8600, Validation Accuracy: 72.52%
# Epoch [8/10], Validation Loss: 0.8136, Validation Accuracy: 72.55%
# Epoch [9/10], Validation Loss: 0.7768, Validation Accuracy: 73.32%
# Epoch [10/10], Validation Loss: 0.7490, Validation Accuracy: 73.88%
# Experimenting with hidden_layers=[512, 256, 128], dropout_prob=0.0, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.7257, Validation Accuracy: 73.42%
# Epoch [2/10], Validation Loss: 0.5885, Validation Accuracy: 78.27%
# Epoch [3/10], Validation Loss: 0.5285, Validation Accuracy: 80.92%
# Epoch [4/10], Validation Loss: 0.4915, Validation Accuracy: 82.43%
# Epoch [5/10], Validation Loss: 0.4754, Validation Accuracy: 83.17%
# Epoch [6/10], Validation Loss: 0.4703, Validation Accuracy: 82.67%
# Epoch [7/10], Validation Loss: 0.4390, Validation Accuracy: 84.15%
# Epoch [8/10], Validation Loss: 0.4270, Validation Accuracy: 84.77%
# Epoch [9/10], Validation Loss: 0.4147, Validation Accuracy: 85.22%
# Epoch [10/10], Validation Loss: 0.4041, Validation Accuracy: 85.82%
# Experimenting with hidden_layers=[512, 256, 128], dropout_prob=0.0, learning_rate=0.001
# Epoch [1/10], Validation Loss: 2.2489, Validation Accuracy: 20.22%
# Epoch [2/10], Validation Loss: 2.1262, Validation Accuracy: 40.88%
# Epoch [3/10], Validation Loss: 1.8391, Validation Accuracy: 40.38%
# Epoch [4/10], Validation Loss: 1.4933, Validation Accuracy: 46.52%
# Epoch [5/10], Validation Loss: 1.2220, Validation Accuracy: 61.87%
# Epoch [6/10], Validation Loss: 1.0511, Validation Accuracy: 67.52%
# Epoch [7/10], Validation Loss: 0.9367, Validation Accuracy: 69.50%
# Epoch [8/10], Validation Loss: 0.8564, Validation Accuracy: 70.67%
# Epoch [9/10], Validation Loss: 0.7975, Validation Accuracy: 72.75%
# Epoch [10/10], Validation Loss: 0.7521, Validation Accuracy: 73.53%
# Experimenting with hidden_layers=[512, 256, 128], dropout_prob=0.2, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.7959, Validation Accuracy: 72.17%
# Epoch [2/10], Validation Loss: 0.6264, Validation Accuracy: 76.05%
# Epoch [3/10], Validation Loss: 0.5561, Validation Accuracy: 79.57%
# Epoch [4/10], Validation Loss: 0.5161, Validation Accuracy: 80.93%
# Epoch [5/10], Validation Loss: 0.4854, Validation Accuracy: 82.57%
# Epoch [6/10], Validation Loss: 0.4685, Validation Accuracy: 82.92%
# Epoch [7/10], Validation Loss: 0.4538, Validation Accuracy: 83.55%
# Epoch [8/10], Validation Loss: 0.4347, Validation Accuracy: 84.28%
# Epoch [9/10], Validation Loss: 0.4282, Validation Accuracy: 84.35%
# Epoch [10/10], Validation Loss: 0.4152, Validation Accuracy: 84.75%
# Experimenting with hidden_layers=[512, 256, 128], dropout_prob=0.2, learning_rate=0.001
# Epoch [1/10], Validation Loss: 2.2536, Validation Accuracy: 28.80%
# Epoch [2/10], Validation Loss: 2.1620, Validation Accuracy: 45.63%
# Epoch [3/10], Validation Loss: 1.9337, Validation Accuracy: 41.47%
# Epoch [4/10], Validation Loss: 1.5417, Validation Accuracy: 44.87%
# Epoch [5/10], Validation Loss: 1.2563, Validation Accuracy: 60.02%
# Epoch [6/10], Validation Loss: 1.0925, Validation Accuracy: 64.48%
# Epoch [7/10], Validation Loss: 0.9808, Validation Accuracy: 67.85%
# Epoch [8/10], Validation Loss: 0.8957, Validation Accuracy: 70.10%
# Epoch [9/10], Validation Loss: 0.8304, Validation Accuracy: 71.75%
# Epoch [10/10], Validation Loss: 0.7813, Validation Accuracy: 73.03%
# Experimenting with hidden_layers=[512, 256, 128], dropout_prob=0.5, learning_rate=0.01
# Epoch [1/10], Validation Loss: 0.9408, Validation Accuracy: 65.90%
# Epoch [2/10], Validation Loss: 0.7127, Validation Accuracy: 71.88%
# Epoch [3/10], Validation Loss: 0.6244, Validation Accuracy: 76.07%
# Epoch [4/10], Validation Loss: 0.5762, Validation Accuracy: 77.90%
# Epoch [5/10], Validation Loss: 0.5329, Validation Accuracy: 80.90%
# Epoch [6/10], Validation Loss: 0.5087, Validation Accuracy: 81.67%
# Epoch [7/10], Validation Loss: 0.4842, Validation Accuracy: 82.58%
# Epoch [8/10], Validation Loss: 0.4749, Validation Accuracy: 82.67%
# Epoch [9/10], Validation Loss: 0.4585, Validation Accuracy: 83.38%
# Epoch [10/10], Validation Loss: 0.4423, Validation Accuracy: 84.03%
# Experimenting with hidden_layers=[512, 256, 128], dropout_prob=0.5, learning_rate=0.001
# Epoch [1/10], Validation Loss: 2.2611, Validation Accuracy: 15.95%
# Epoch [2/10], Validation Loss: 2.1897, Validation Accuracy: 30.60%
# Epoch [3/10], Validation Loss: 2.0478, Validation Accuracy: 42.08%
# Epoch [4/10], Validation Loss: 1.8093, Validation Accuracy: 39.83%
# Epoch [5/10], Validation Loss: 1.5612, Validation Accuracy: 48.68%
# Epoch [6/10], Validation Loss: 1.3589, Validation Accuracy: 54.67%
# Epoch [7/10], Validation Loss: 1.2017, Validation Accuracy: 57.38%
# Epoch [8/10], Validation Loss: 1.0919, Validation Accuracy: 60.10%
# Epoch [9/10], Validation Loss: 1.0147, Validation Accuracy: 62.57%
# Epoch [10/10], Validation Loss: 0.9574, Validation Accuracy: 65.20%
# Best Configuration: {'hidden_layers': [512, 256, 128], 'dropout_prob': 0.0, 'learning_rate': 0.01, 'val_loss': 0.40408559888601303, 'val_accuracy': 85.81666666666666}

# %% [markdown]
# ## Question 3
# Implement a CNN backbone model using pytorch.
# #### a) Build a small CNN model consisting of 5 convolution layers. Each convolution layer would be followed by a ReLU activation and a max pooling layer

# %%
import torch
import torch.nn as nn

class CNN_Model(nn.Module):
    def __init__(self, num_kernels=[16, 32, 64, 128, 256], kernel_size=3):
        super(CNN_Model, self).__init__()

        self.layer1_conv = nn.Conv2d(1, num_kernels[0], kernel_size, padding=1)
        self.layer1_activ = nn.ReLU()
        self.layer1_maxpool = nn.MaxPool2d(2, stride=2)

        self.layer2_conv = nn.Conv2d(num_kernels[0], num_kernels[1], kernel_size, padding=1)
        self.layer2_activ = nn.ReLU()
        self.layer2_maxpool = nn.MaxPool2d(2, stride=2)

        self.layer3_conv = nn.Conv2d(num_kernels[1], num_kernels[2], kernel_size, padding=1)
        self.layer3_activ = nn.ReLU()
        self.layer3_maxpool = nn.MaxPool2d(2, stride=2)

        self.layer4_conv = nn.Conv2d(num_kernels[2], num_kernels[3], kernel_size, padding=1)
        self.layer4_activ = nn.ReLU()
        self.layer4_maxpool = nn.MaxPool2d(2, stride=2)

        self.layer5_conv = nn.Conv2d(num_kernels[3], num_kernels[4], kernel_size, padding=1)
        self.layer5_activ = nn.ReLU()
        self.layer5_maxpool = nn.MaxPool2d(2, stride=2)

        self.fc1 = nn.Linear(num_kernels[4] * 1 * 1, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = self.layer1_conv(x)
        x = self.layer1_activ(x)
        x = self.layer1_maxpool(x)

        x = self.layer2_conv(x)
        x = self.layer2_activ(x)
        x = self.layer2_maxpool(x)

        x = self.layer3_conv(x)
        x = self.layer3_activ(x)
        x = self.layer3_maxpool(x)

        x = self.layer4_conv(x)
        x = self.layer4_activ(x)
        x = self.layer4_maxpool(x)

        x = self.layer5_conv(x)
        x = self.layer5_activ(x)
        x = self.layer5_maxpool(x)

        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# Example instantiation
model = CNN_Model()

# %%
model
# Out:
# CNN_Model(
#   (layer1_conv): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (layer1_activ): ReLU()
#   (layer1_maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer2_conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (layer2_activ): ReLU()
#   (layer2_maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer3_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (layer3_activ): ReLU()
#   (layer3_maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer4_conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (layer4_activ): ReLU()
#   (layer4_maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (layer5_conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (layer5_activ): ReLU()
#   (layer5_maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=256, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=10, bias=True)
# )

# %% [markdown]
# #### b) Experiment with different kernel size, number of kernel each layer (keep number of filter same in each layer, double it in each layer etc) and settle with a combination which performs the best for the given problem

# %%
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split

# Define transformations for the dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))  # Normalize to [-1, 1] range
])

# Download and load the FashionMNIST dataset
dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)

# Define the size of each split
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

# Split the dataset
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# Create data loaders for each split
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Training and evaluation function
def train_and_evaluate(model, train_loader, val_loader, num_epochs, learning_rate, criterion):
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    
    for epoch in range(num_epochs):
        model.train()
        for images, labels in train_loader:
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_loss /= len(val_loader)
        val_accuracy = 100 * correct / total
        print(f'Epoch [{epoch+1}/{num_epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
    
    return val_loss, val_accuracy

# Hyperparameter configurations
kernel_sizes = [2, 1]
num_kernels_configs = [
    [16, 32, 64, 128, 256],
    [32, 64, 128, 256, 256]
]
learning_rates = [0.01, 0.001]
num_epochs = 10

best_val_loss = float('inf')
best_model = None
best_config = {}

# Experiment with different hyperparameters
for kernel_size in kernel_sizes:
    for num_kernels in num_kernels_configs:
        for lr in learning_rates:
            print(f'Experimenting with kernel_size={kernel_size}, num_kernels={num_kernels}, learning_rate={lr}')
            model = CNN_Model(num_kernels=num_kernels, kernel_size=kernel_size)
            criterion = nn.CrossEntropyLoss()
            val_loss, val_accuracy = train_and_evaluate(model, train_loader, val_loader, num_epochs, lr, criterion)
            
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model = model
                best_config = {
                    'kernel_size': kernel_size,
                    'num_kernels': num_kernels,
                    'learning_rate': lr,
                    'val_loss': val_loss,
                    'val_accuracy': val_accuracy
                }

print(f'Best Configuration: {best_config}')
# Out:
# Experimenting with kernel_size=2, num_kernels=[16, 32, 64, 128, 256], learning_rate=0.01
# Epoch [1/10], Validation Loss: 2.3011, Validation Accuracy: 16.60%
# Epoch [2/10], Validation Loss: 2.2978, Validation Accuracy: 9.58%
# Epoch [3/10], Validation Loss: 2.2809, Validation Accuracy: 34.00%
# Epoch [4/10], Validation Loss: 1.2359, Validation Accuracy: 52.72%
# Epoch [5/10], Validation Loss: 0.8204, Validation Accuracy: 67.92%
# Epoch [6/10], Validation Loss: 0.7345, Validation Accuracy: 68.52%
# Epoch [7/10], Validation Loss: 0.6791, Validation Accuracy: 72.62%
# Epoch [8/10], Validation Loss: 0.5836, Validation Accuracy: 78.30%
# Epoch [9/10], Validation Loss: 0.5306, Validation Accuracy: 80.08%
# Epoch [10/10], Validation Loss: 0.5302, Validation Accuracy: 79.35%
# Experimenting with kernel_size=2, num_kernels=[16, 32, 64, 128, 256], learning_rate=0.001
# Epoch [1/10], Validation Loss: 2.3034, Validation Accuracy: 9.72%
# Epoch [2/10], Validation Loss: 2.3026, Validation Accuracy: 9.72%
# Epoch [3/10], Validation Loss: 2.3018, Validation Accuracy: 9.72%
# Epoch [4/10], Validation Loss: 2.3011, Validation Accuracy: 9.72%
# Epoch [5/10], Validation Loss: 2.3004, Validation Accuracy: 9.72%
# Epoch [6/10], Validation Loss: 2.2997, Validation Accuracy: 9.90%
# Epoch [7/10], Validation Loss: 2.2990, Validation Accuracy: 12.45%
# Epoch [8/10], Validation Loss: 2.2981, Validation Accuracy: 14.70%
# Epoch [9/10], Validation Loss: 2.2972, Validation Accuracy: 15.87%
# Epoch [10/10], Validation Loss: 2.2960, Validation Accuracy: 16.50%
# Experimenting with kernel_size=2, num_kernels=[32, 64, 128, 256, 256], learning_rate=0.01
# Epoch [1/10], Validation Loss: 2.2939, Validation Accuracy: 22.78%
# Epoch [2/10], Validation Loss: 1.7124, Validation Accuracy: 43.67%
# Epoch [3/10], Validation Loss: 0.8870, Validation Accuracy: 63.32%
# Epoch [4/10], Validation Loss: 0.7691, Validation Accuracy: 71.90%
# Epoch [5/10], Validation Loss: 0.6542, Validation Accuracy: 76.12%
# Epoch [6/10], Validation Loss: 0.5732, Validation Accuracy: 78.85%
# Epoch [7/10], Validation Loss: 0.5239, Validation Accuracy: 80.62%
# Epoch [8/10], Validation Loss: 0.4931, Validation Accuracy: 82.13%
# Epoch [9/10], Validation Loss: 0.4729, Validation Accuracy: 82.92%
# Epoch [10/10], Validation Loss: 0.4459, Validation Accuracy: 84.00%
# Experimenting with kernel_size=2, num_kernels=[32, 64, 128, 256, 256], learning_rate=0.001
# Epoch [1/10], Validation Loss: 2.3014, Validation Accuracy: 16.28%
# Epoch [2/10], Validation Loss: 2.3004, Validation Accuracy: 17.82%
# Epoch [3/10], Validation Loss: 2.2993, Validation Accuracy: 18.57%
# Epoch [4/10], Validation Loss: 2.2982, Validation Accuracy: 19.23%
# Epoch [5/10], Validation Loss: 2.2969, Validation Accuracy: 21.40%
# Epoch [6/10], Validation Loss: 2.2953, Validation Accuracy: 23.12%
# Epoch [7/10], Validation Loss: 2.2934, Validation Accuracy: 23.98%
# Epoch [8/10], Validation Loss: 2.2910, Validation Accuracy: 24.80%
# Epoch [9/10], Validation Loss: 2.2877, Validation Accuracy: 29.52%
# Epoch [10/10], Validation Loss: 2.2832, Validation Accuracy: 38.50%
# Experimenting with kernel_size=1, num_kernels=[16, 32, 64, 128, 256], learning_rate=0.01
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 79
#      77 model = CNN_Model(num_kernels=num_kernels, kernel_size=kernel_size)
#      78 criterion = nn.CrossEntropyLoss()
# ---> 79 val_loss, val_accuracy = train_and_evaluate(model, train_loader, val_loader, num_epochs, lr, criterion)
#      81 if val_loss < best_val_loss:
#      82     best_val_loss = val_loss
#
# Cell In[10], line 34, in train_and_evaluate(model, train_loader, val_loader, num_epochs, learning_rate, criterion)
#      32 model.train()
#      33 for images, labels in train_loader:
# ---> 34     outputs = model(images)
#      35     loss = criterion(outputs, labels)
#      36     optimizer.zero_grad()
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[8], line 53, in CNN_Model.forward(self, x)
#      50 x = self.layer5_maxpool(x)
#      52 x = x.view(x.size(0), -1)
# ---> 53 x = self.fc1(x)
#      54 x = self.fc2(x)
#      56 return x
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (64x1024 and 256x256)

# %% [markdown]
# #### c) Try different weight initialization methods (random, Xavier, He)

# %%
def initialize_weights(model, method='xavier'):
    for m in model.modules():
        if isinstance(m, nn.Conv2d):
            if method == 'xavier':
                nn.init.xavier_uniform_(m.weight)
            elif method == 'he':
                nn.init.kaiming_uniform_(m.weight, nonlinearity='relu')
            elif method == 'random':
                nn.init.uniform_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

# Example usage
model = CNN_Model(num_kernels=best_config['num_kernels'], kernel_size=best_config['kernel_size'])
initialize_weights(model, method='xavier')
initialize_weights(model, method='he')
initialize_weights(model, method='random')

# %% [markdown]
# #### d) After extracting feature from CNN model use MLP for classification

# %%
# Initialize the models
cnn_model = CNN_Model(num_kernels=best_config['num_kernels'], kernel_size=best_config['kernel_size'])
mlp_model = MLP()

# Initialize weights if needed
# initialize_weights(cnn_model, method='xavier')
# initialize_weights(mlp_model, method='xavier')

# Criterion
criterion = nn.CrossEntropyLoss()

# Train and evaluate
val_loss, val_accuracy = train_and_evaluate(cnn_model, mlp_model, train_loader, val_loader, num_epochs, learning_rate, criterion)
print(f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
